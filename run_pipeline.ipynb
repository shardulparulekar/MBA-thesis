# %% [markdown]
# # Explaining and Predicting State-Level Variation in UPI Adoption Intensity Across India
#
# Run the cell below to execute the full pipeline exactly as used in the thesis: data cleaning, feature construction, Stage 1 (explanatory regressions), Stage 2 (Ridge vs. Random Forest prediction), and every figure and table.
#
# Takes a few minutes to run fully. All console output and figures render inline below.

# %%
# %run full_pipeline_v2.py

# %% [markdown]
# ---
# That's the full run. Exported CSVs (`table_3_2_summary_stats.csv`, `stage2_predictions.csv`, etc.) and all figures are saved in this same folder, browsable from the JupyterLab file panel on the left.
